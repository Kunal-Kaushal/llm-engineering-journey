# %%
import tiktoken
encoding = tiktoken.encoding_for_model("gpt-4.1-mini")
tokens=encoding.encode("Hi my name is Kunal Kaushal and I like Apple pie")

# %%
tokens
# Out:
# [12194,
#  922,
#  1308,
#  382,
#  658,
#  23326,
#  14234,
#  1776,
#  280,
#  326,
#  357,
#  1299,
#  10124,
#  5148]

# %%
for token_id in tokens:
    token_text = encoding.decode([token_id])
    print(f"{token_id} = {token_text}")
# Out:
# 12194 = Hi
# 922 =  my
# 1308 =  name
# 382 =  is
# 658 =  K
# 23326 = unal
# 14234 =  Ka
# 1776 = ush
# 280 = al
# 326 =  and
# 357 =  I
# 1299 =  like
# 10124 =  Apple
# 5148 =  pie

# %%
encoding.decode([326])
# Out:
# ' and'

# %%
import os 
from dotenv import load_dotenv
load_dotenv(override=True)
gemini_api_key = os.getenv("GEMINI_API_KEY")
GEMINI_BASE_URL = "https://generativelanguage.googleapis.com/v1beta/openai/"

# %%
from openai import OpenAI
gemini = OpenAI(base_url = GEMINI_BASE_URL, api_key=gemini_api_key)
response = gemini.chat.completions.create(model="gemini-2.5-flash-lite", messages=[{"role" : "system","content":"You are a helpful asisstent"},
                                                                                    {"role" : "user","content":"Hey! I am Kunal"}])
response.choices[0].message.content
# Out:
# "Hi Kunal! It's nice to meet you. How can I help you today?"

# %%
model = "gemini-2.5-flash-lite"
messages = [
    {"role": "system", "content": "You are a helpful assistant"},
    {"role": "user", "content": "What's my name?"}
    ]

# %%
response = gemini.chat.completions.create(model=model,messages=messages)
response.choices[0].message.content
# Out:
# "I do not have access to your personal information, including your name. I am a large language model, an AI, and I don't have a memory of past conversations or any way to identify individual users."
