# %%
import os
from dotenv import load_dotenv
from web_scraper import fetch_website_contents
from IPython.display import Markdown, display
from openai import OpenAI

# %%
GEMINI_BASE_URL = "https://generativelanguage.googleapis.com/v1beta/openai/"
load_dotenv(override=True)
google_api_key = os.getenv('GOOGLE_API_KEY')
gemini = OpenAI(base_url=GEMINI_BASE_URL, api_key=google_api_key)
response = gemini.chat.completions.create(model="gemini-2.5-flash-lite", messages=[{"role": "user", "content": "What is 2+2?"}])
print(response.choices[0].message.content)
# Out:
# 2 + 2 = 4

# %%
message = "Hello gemini! This is my first ever message to you. hi!"
messages = [{"role": "user", "content": message}]
messages
# Out:
# [{'role': 'user',
#   'content': 'Hello gemini! This is my first ever message to you. hi!'}]

# %%
response = gemini.chat.completions.create(model="gemini-2.5-flash", messages=messages)
print(response.choices[0].message.content)
# Out:
# Hello there! 👋 It's wonderful to meet you.
#
# Welcome! I'm glad you're here. How can I help you today? Or just saying hi back is perfectly fine too! 😊

# %%
kkye = fetch_website_contents("https://kunalkaushal.tech")
print(kkye)
# Out:
# Kunal Kaushal | AI & ML Developer
#
# KK
# .
# About
# Skills
# Projects
# Certifications
# Hi, I'm
# Kunal Kaushal
# |
# AI & ML student building intelligent systems and scalable backend applications. Interested in cybersecurity, cloud infrastructure, and solving real-world problems through technology.
# Let's Talk
# About Me
# I am an AI & ML student passionate about building intelligent systems and scalable backend applications.
# My work focuses on developing practical AI-powered tools using Python, FastAPI, and cloud platforms like AWS and GCP. I enjoy designing systems that combine machine learning with real-world applications.
# Recently, I started implementing python programming skills in Cybersecurity including network analysis and vulnerability assessment while building practical systems using AI and cloud technologies.
# Education
# B.Tech. in Artificial Intelligence and Machine Learning
# Oct 2023 – 2027
# GL Bajaj Institute of Technology and Management, Greater Noida, UP
# Technical Skills
# Programming
# Python
# C++
# C
# SQL
# Cloud & DevOps
# AWS
# GCP
# Terraform
# Docker
# CI/CD
# Firestore
# AI/ML & GenAI
# Agentic AI
# Generative AI
# Gemini Models
# Machine Learning
# Google ADK
# Backend & Development
# Flask API
# FastAPI
# RESTful APIs
# Git / GitHub
# VS Code
# Computer Science Fundamentals
# Data Structures and Algorithms
# Problem Solving
# Cybersecurity
# Network Analysis
# Vulnerability Scanning
# Nmap
# Featured Projects
# AI-Powered Leave Management System
# A multi-agent AI system with 5 specialized agents using Google ADK and Gemini 2.0 Flash for intelligent leave management. Backend built with FastAPI and integrated with Google Cloud Firestore.
# Python
# Google ADK
# FastAPI
# GCP
# Multi-Agent AI
# GEN-AI Resume Analyzer
# AI-powered resume analyzer with Google Gemini AI for job-description matching. Achieved 95%+ text extraction accuracy. Robust Flask REST API deployed on Google Cloud Run with Docker.
# Flask API
# React
# LLM API
# CI/CD
# GCP
# Network Port Scanner & Vulnerability Assessment Tool
# Python-based network scanner for detecting open TCP ports, iden

# %%
system_prompt = """
You are an helpful assistant that analyzes the contents of the website,
and provides a short summary, ignoring text that might be navigation related.
Respond in markdown. Do not wrap the response in code blocks. - respond just with markdown.
 """

# %%
user_prompt = """
Here are the contents of the website.
Provide a short summary of this website.
if it includes news or announcements, then summarize these too.
"""

# %%
def messages_for(website):
    return [
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt + website}
    ]

# %%
messages_for(kkye)
# Out:
# [{'role': 'system',
#   'content': '\nYou are an helpful assistant that analyzes the contents of the website,\nand provides a short summary, ignoring text that might be navigation related.\nRespond in markdown. Do not wrap the response in code blocks. - respond just with markdown.\n '},
#  {'role': 'user',
#   'content': "\nHere are the contents of the website.\nProvide a short summary of this website.\nif it includes news or announcements, then summarize these too.\nKunal Kaushal | AI & ML Developer\n\nKK\n.\nAbout\nSkills\nProjects\nCertifications\nHi, I'm\nKunal Kaushal\n|\nAI & ML student building intelligent systems and scalable backend applications. Interested in cybersecurity, cloud infrastructure, and solving real-world problems through technology.\nLet's Talk\nAbout Me\nI am an AI & ML student passionate about building intelligent systems and scalable backend applications.\nMy work focuses on developing practical AI-powered tools using Python, FastAPI, and cloud platforms like AWS and GCP. I enjoy designing systems that combine machine learning with real-world applications.\nRecently, I started implementing python programming skills in Cybersecurity including network analysis and vulnerability assessment while building practical systems using AI and cloud technologies.\nEducation\nB.Tech. in Artificial Intelligence and Machine Learning\nOct 2023 – 2027\nGL Bajaj Institute of Technology and Management, Greater Noida, UP\nTechnical Skills\nProgramming\nPython\nC++\nC\nSQL\nCloud & DevOps\nAWS\nGCP\nTerraform\nDocker\nCI/CD\nFirestore\nAI/ML & GenAI\nAgentic AI\nGenerative AI\nGemini Models\nMachine Learning\nGoogle ADK\nBackend & Development\nFlask API\nFastAPI\nRESTful APIs\nGit / GitHub\nVS Code\nComputer Science Fundamentals\nData Structures and Algorithms\nProblem Solving\nCybersecurity\nNetwork Analysis\nVulnerability Scanning\nNmap\nFeatured Projects\nAI-Powered Leave Management System\nA multi-agent AI system with 5 specialized agents using Google ADK and Gemini 2.0 Flash for intelligent leave management. Backend built with FastAPI and integrated with Google Cloud Firestore.\nPython\nGoogle ADK\nFastAPI\nGCP\nMulti-Agent AI\nGEN-AI Resume Analyzer\nAI-powered resume analyzer with Google Gemini AI for job-description matching. Achieved 95%+ text extraction accuracy. Robust Flask REST API deployed on Google Cloud Run with Docker.\nFlask API\nReact\nLLM API\nCI/CD\nGCP\nNetwork Port Scanner & Vulnerability Assessment Tool\nPython-based network scanner for detecting open TCP ports, iden"}]

# %%
def summarize_website(url):
    print(f"Fetching website {url}...")
    website = fetch_website_contents(url)
    response = gemini.chat.completions.create(
        model="gemini-2.5-flash", 
        messages=messages_for(website)
    )
    return response.choices[0].message.content

# %%
summarize_website("https://kunalkaushal.tech")
# Out:
# Fetching website https://kunalkaushal.tech...
# 'This website belongs to Kunal Kaushal, an AI & ML student and developer. It serves as his personal portfolio, highlighting his skills, projects, and educational background. Kunal specializes in building intelligent systems and scalable backend applications, with a focus on practical AI-powered tools using Python, FastAPI, and cloud platforms like AWS and GCP. He also has a growing interest in cybersecurity, implementing Python skills for network analysis and vulnerability assessment.\n\nKey projects include an AI-Powered Leave Management System (a multi-agent AI system with Google ADK and Gemini 2.0 Flash) and a GEN-AI Resume Analyzer (using Google Gemini AI for job-description matching). His technical skills span programming (Python, C++, SQL), Cloud & DevOps (AWS, GCP, Terraform, Docker), AI/ML & GenAI (Agentic AI, Gemini Models, Machine Learning), Backend & Development (Flask API, FastAPI), and Cybersecurity (Network Analysis, Nmap).'

# %%
def display_summary(url):
    summary = summarize_website(url)
    display(Markdown(summary))

# %%
display_summary("https://cnn.com")
# Out:
# Fetching website https://cnn.com...
# This website is CNN, a major news platform providing breaking news, latest news, and videos across a comprehensive range of topics. Its coverage includes global and regional news (US, World, Africa, Americas, Asia, Europe, Middle East, UK), politics (US Politics, elections, figures like Trump), business (tech, media, markets, investing), health, entertainment, style, travel, sports, science, climate, and weather. The site specifically highlights ongoing coverage of the **Ukraine-Russia War** and the **Israel-Hamas War**.
